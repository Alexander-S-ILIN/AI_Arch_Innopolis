# %% [markdown]
# ![Innopolis%20logo-3.png](attachment:Innopolis%20logo-3.png)

# %% [markdown]
# <hr style="border: 2px solid green;" />
# <br>
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid orange 2px; padding: 20px"> <b>
#
#  ✅ КУРС: АРХИТЕКТОР В ОБЛАСТИ ИСКУССТВЕННОГО ИНТЕЛЛЕКТА</b><br>
#     </div>
# <hr style="border: 2px solid green;" />

# %% [markdown]
# <br>
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid orange 2px; padding: 20px"> <b>
#     ✅ СТУДЕНТ: ИЛЬИН АЛЕКСАНДР СЕРГЕЕВИЧ, Telegram: @AlexanderILIN </b><br>
#
#     группа : Группа: 1 и 2 потоки / группа 2
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px"> <b>✅ ДОМАШНЕЕ ЗАДАНИЕ ПО ТЕМЕ:  «Среды разработки (IDE) для Python. Подготовка рабочего места»
#
#     Дата выставления задания 27.06.2023
#
#     Дата выполнения задания 01.07.2023
#
# </div>

# %% [markdown]
# <h1 id="tocheading">СОДЕРЖАНИЕ</h1>
# <div id="toc"></div>

# %%
# %autosave 300
# Out:
# Autosaving every 300 seconds

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# ## Формулировка задания
# Разверните рабочую среду Jupyter Notebook на вашем локальном компьютере.
#
# Для этого необходимо установить Python и / или пакет Anaconda.
#
# После этого вызовите через командную строку запуск Jupyter сервера.
#
# В открывшемся браузере необходимо в первом блоке Jupyter Notebook
# запустить команду print с указанием вашего полного ФИО.
#
# Например -
# print(‘Иванов Иван Иванович’)

# %% [markdown]
# ## Ожидаемый результат
# Результатом вашей работы будет скрин вашего рабочего места Jupyter
# Notebook с выводом результата команды print.

# %% [markdown]
# <hr style="border: 2px solid green;" />
# <br>
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid orange 2px; padding: 20px"> <b>
#     ✅ СРЕДЫ РАЗРАБОТКИ ДЛЯ (IDE) ДЛЯ PYTHON. ПОДГОТОВКА РАБОЧЕГО МЕСТА"  </b><br>
#     </div>
# <br>
# <hr style="border: 2px solid green;" />

# %% [markdown]
# ## Скриншот загрузки пакета Anaconda

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28909%29.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28909%29.png)

# %% [markdown]
# ## Скриншоты загрузки пакета PyCharm

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28910%29.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28910%29.png)

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28912%29.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28912%29.png)

# %% [markdown]
# ## Скриншот загрузки Jupyter Notebook

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28913%29.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%28913%29.png)

# %% [markdown]
# ## Вывод командой print c указанием ФИО студента, исполнившего работу

# %%
print('Ильин Александр Сергеевич')
# Out:
# Ильин Александр Сергеевич

# %% [markdown]
# ## Общий вывод по итогам выполнени домашнего  задания №3

# %% [markdown]
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px"> <b> Общий вывод по выполненому домашнему заданию №3 </b><br>

# %% [markdown]
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px"> <b>✅ В результате исполнения задания:  </b><br>
#
# - Произведена загрузка пакета Anaconda с установкой базового комплекта приложений, в том числе Jupyter Notebook и Spyder (IDE).
#
# -  Осуществлена загрузка пакета PyCharm (IDE) и произведена его активация.
#
# - Создан файл Jupyter Notebook для выполнения домашнего задания.
#
# - Произведен запуск команды print в тетради Jupyter Notebook c выводом ФИО студента, исполнившего домашнее задание.
#  </div>
